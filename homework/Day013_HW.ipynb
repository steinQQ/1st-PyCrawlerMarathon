# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
resp = requests.get(url, cookies={'over18': '1'})
soup = BeautifulSoup(resp.text)
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")
# print(r.text)
df = pd.DataFrame(columns=['作者', '標題','時間'])
i=0
for d in soup.find_all(class_="title"):
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        data=r.find_all(class_='article-meta-value')
        df.loc[i] = [data[0].text, data[2].text, data[3].text]
        i+=1
    except:
        continue
    
df.iloc[0]
# Out:
# 作者                   Muma5566 (木馬56)
# 標題    [新聞] Tatum:會努力幫助球隊贏球，自己也想入選全明星
# 時間          Wed Dec 11 13:40:59 2019
# Name: 0, dtype: object

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
df
# Out:
#                                    作者                                      標題  \
# 0                     Muma5566 (木馬56)          [新聞] Tatum:會努力幫助球隊贏球，自己也想入選全明星
# 1                     TheBatman (蝙蝠俠)         [花邊] Nelson談論當年Howard在魔術的"魔獸人生"
# 2                   LinBaoYan (負酬者聯盟)                   [新聞] 卡特第1500場出賽 史上第5人
# 3                   thnlkj0665 (灰色地帶)               [花邊] 厄文持續缺賽 錯失激勵獎金12.5萬美元
# 4   kairiyu (E N O U G H  is  enough)     [花邊] 當湖人主場播放歌手Lizzo歌曲時，本人在場邊直接表演露臀舞
# 5                innocent8675 (坤溪戴維斯)                                    [花邊]
# 6                  NSYSUheng (Madara)              [花邊] KD重申了自己想要擁有一支NBA球隊的願望
# 7                        tmac4ever ()       Re: [花邊] Jimmy Butler的instagram貼文
# 8                      Israfil (贖罪聖音)                 [新聞] 三分砲火猛烈 伯坦斯：籃框實在太寬了
# 9                   thnlkj0665 (灰色地帶)         [情報] New Balance為Kawhi架設看板感謝多倫多
# 10                      lovea (lovea)           [花邊] Tacko Fall：KG是傳奇，見到他對我意義
# 11                    Darren2012 (達倫)                    [討論] 08年京奧男籃的西班牙很謎嗎?
# 12                     pneumo (超☆冒險蓋)                    [討論] LBJ在投三分球之前的準備動作
# 13                       whoAU (你是誰？)             [情報] 全能後衛！Ish Smith在暫停時幫忙拖地
# 14                  LinBaoYan (負酬者聯盟)                 [花邊] 前賽爾提克球員因未尊重中國國歌遭罰款
# 15                     s27052705 (小飽)                         [花邊] 舞王賽後發聲：跟隨我
# 16                      ghost069 (阿鬼)                  [討論] 哈登的後撤三分是現今最難被防守的嗎
# 17                         Vedan (味丹)                      [公告] 樂透取消及未來不再開啟樂透
# 18         qazwsx879345 (Rajon Rondo)                           [公告] 版主上任相關事項
# 19                     JerroLi (銀色小刀)  [情報] SEASON Schedule 賽程 December 19–20
# 20                dragon803 (好想去露營啊~)          [公告]是否禁止basketball top 5文章投票開始
#
#                           時間
# 0   Wed Dec 11 13:40:59 2019
# 1   Wed Dec 11 13:52:04 2019
# 2   Wed Dec 11 13:55:41 2019
# 3   Wed Dec 11 14:38:00 2019
# 4   Wed Dec 11 14:59:16 2019
# 5   Wed Dec 11 14:59:57 2019
# 6   Wed Dec 11 15:39:17 2019
# 7   Wed Dec 11 16:21:42 2019
# 8   Wed Dec 11 16:56:49 2019
# 9   Wed Dec 11 17:39:27 2019
# 10  Wed Dec 11 17:54:26 2019
# 11  Wed Dec 11 19:33:05 2019
# 12  Wed Dec 11 20:50:32 2019
# 13  Wed Dec 11 20:59:53 2019
# 14  Wed Dec 11 21:28:45 2019
# 15  Wed Dec 11 22:00:02 2019
# 16  Wed Dec 11 22:53:02 2019
# 17  Mon Jun 24 15:08:02 2019
# 18  Fri Oct 25 10:44:03 2019
# 19  Fri Nov 29 00:46:01 2019
# 20  Sun Dec  8 23:55:00 2019

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
r = requests.get(url, cookies={'over18': '1'})

soup = BeautifulSoup(r.text, "html5lib")
# print(r.text)
df = pd.DataFrame(columns=['作者', '標題','時間'])
i=0
for d in soup.find_all(class_="title"):
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href'], cookies={'over18': '1'}).text, "html5lib")
        data=r.find_all(class_='article-meta-value')
        df.loc[i] = [data[0].text, data[2].text, data[3].text]
        i+=1
    except:
        continue
    
df
# Out:
#                           作者                              標題  \
# 0              m4vu0 (m4vu0)                     [問卦] 理工女怎麼追
# 1        rockon15 (水之呼吸－炭治郎)     Re: [新聞] 楊蕙如打造暗黑兵團，卡神的「業主們」
# 2   keane9112 (拎北逮頑郎 拎北反支那啦)              [問卦] 有無推噓數字不準確的八卦？
# 3          Roger0123 (Roger)        [問卦] 有沒有什麼東西你覺得你一輩子都不可能懂
# 4             johnhmj (耗呆肥羊)                [問卦] 請問你要看哪一部電影？
# 5               andrewkuo ()         [新聞] 特朗普彈劾案：總統涉嫌濫用總統權力、
# 6           poppyvampire ( )                  [問卦] 肥宅的極限是什麼?
# 7              a2016596 (火花)                  [問卦]  狗勾睡很熟怎摸辦
# 8              guets (guets)             [問卦] 如何一句話讓中國人這個反應?
# 9             Anddyliu (安滴滴)  Re: [新聞] 10日後剩1位法官 WTO上訴機構瀕臨瓦解
# 10           Roosevelt (木村哥)    Re: [新聞] 青年對藍營不分區名單感到失望 張善政：
# 11   chi12345678 (♥讀經典 FY細角)                [問卦] 把咲唸成咩不行嗎？qq
# 12            oooo (法性本寂隨緣轉)     Re: [爆卦] 童仲彥要創黨啦!!!!!!!!!!!
# 13          judas666 (judas)             [問卦] 為何 台灣沒女子大學？？？？
# 14  GenghisKhan (館長用朕名號 請付費)  Re: [新聞] 紅色OTT襲台 台灣究竟管不管？專法成焦點
# 15        ilovettb (笑著笑著就哭了)         Re: [問卦] 《絕命毒師》人物設定的八卦?
# 16         arsonlolita (蘿莉塔)          [公告] 八卦板板規(2019.08.21)
# 17          arsonlolita (板主)                   [公告] 宣導禁止回文政問
# 18                 witty ( )     [協尋] 11/20高市大順一路548號順明街行車記錄
# 19             Amybook (123)          協尋12/6台中市向上路往精科五路行車記錄器
# 20            Bignana (天劍煙雨)              [公告] 一劍無悔，十二月置底閒聊文
#
#                           時間
# 0   Wed Dec 11 22:38:30 2019
# 1   Wed Dec 11 22:39:06 2019
# 2   Wed Dec 11 22:39:20 2019
# 3   Wed Dec 11 22:41:28 2019
# 4   Wed Dec 11 22:42:02 2019
# 5   Wed Dec 11 22:42:35 2019
# 6   Wed Dec 11 22:46:06 2019
# 7   Wed Dec 11 22:46:39 2019
# 8   Wed Dec 11 22:47:47 2019
# 9   Wed Dec 11 22:48:00 2019
# 10  Wed Dec 11 22:48:11 2019
# 11  Wed Dec 11 22:48:14 2019
# 12  Wed Dec 11 22:50:27 2019
# 13  Wed Dec 11 22:50:58 2019
# 14  Wed Dec 11 22:52:40 2019
# 15  Wed Dec 11 22:54:34 2019
# 16  Wed Aug 21 08:33:39 2019
# 17  Wed Nov 20 09:14:42 2019
# 18  Sun Nov 24 21:28:01 2019
# 19  Sun Dec  8 01:29:53 2019
# 20  Mon Dec  2 23:13:15 2019
