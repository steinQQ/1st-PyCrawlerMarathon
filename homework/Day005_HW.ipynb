# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
import requests
import json
import pandas as pd

r_pop = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
r_npop = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=false')

resp_pop = r_pop.text
resp_npop = r_npop.text

#data_pop = json.loads(resp_pop)
#data_npop = json.loads(resp_npop)
df_pop = pd.read_json(resp_pop)
df_npop = pd.read_json(resp_npop)


##################################

df_pop = pd.read_json(resp_pop)
df_npop = pd.read_json(resp_npop)

print('熱門文章有%s筆資料\n' % len(df_pop))
print('非熱門文章有%s筆資料\n' % len(df_npop))
# Out:
# 熱門文章有30筆資料
#
# 非熱門文章有30筆資料

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
cols_name = ['標題', '貼文時間', '留言人數', '按讚人數']

# 熱門文章
df_pop_r = df_pop[['title', 'createdAt', 'commentCount', 'likeCount']]
df_pop_r.columns = cols_name
print('熱門文章:\n')
df_pop_r
# Out:
# 熱門文章:
#                                   標題                      貼文時間  留言人數  按讚人數
# 0                             同學你的貓貓  2019-12-02T12:11:28.555Z    76  5093
# 1               我到底養了什麼貓....（...微西斯）  2019-12-02T11:45:50.709Z    52  2086
# 2                      有這麼不爽嗎(･ัω･ั)  2019-12-02T08:31:17.626Z    23   878
# 3                         餵養的浪貓得了乳腺瘤  2019-12-02T05:29:49.540Z    20   666
# 4                             我家的老阿公  2019-12-02T06:22:36.958Z    16   648
# 5                     我發誓牠們的食物是一樣的……  2019-12-02T15:47:50.672Z    14   490
# 6               散步好夥伴🐶漆黑寒冷的夜晚也找得到便便💩  2019-12-02T02:51:47.393Z     0   306
# 7   #CP值爆棚🔥包準可以安心侍奉主子們的安心居家清潔劑～隆重登場！  2019-12-03T07:01:36.591Z     5   301
# 8                               覺得認同  2019-12-02T16:16:39.331Z    11   280
# 9                       我在日本養了一隻貓(圖多  2019-12-02T02:38:35.799Z     7   213
# 10                          你怎麼站起來了！  2019-12-02T14:42:42.738Z     8    88
# 11                             #急#刺蝟  2019-12-02T05:06:34.886Z    17    84
# 12                                送養  2019-12-02T02:36:37.309Z     5    69
# 13                            是我太髒嗎?  2019-12-02T09:16:23.658Z     3    63
# 14                           比特BB的心酸  2019-12-03T03:00:15.230Z    26    62
# 15                          直接抓到犯罪證據  2019-12-02T14:43:24.475Z     1    59
# 16                             同學你的貓  2019-12-02T17:33:55.812Z     5    44
# 17                         養了一隻便便製造機  2019-12-02T19:36:06.064Z    12    38
# 18                         若要抱貓，必先成貓  2019-12-02T05:44:06.710Z     3    35
# 19                             中台小貓咪  2019-12-02T15:28:25.729Z     1    34
# 20                         我有一隻可愛的來福  2019-12-02T14:32:37.716Z     7    33
# 21                           我家曠世怨婦🐱  2019-12-02T06:56:01.120Z     0    25
# 22                     淘寶訂可爾必斯送來...?  2019-12-02T08:32:40.657Z     3    23
# 23                       #圖多 萬用的奴才肩膀  2019-12-02T10:49:21.771Z     0    21
# 24                       床要被你們壓壞啦啊啊啊  2019-12-02T13:09:49.509Z     4    20
# 25                             龍貓_荳荳  2019-12-03T03:53:17.954Z     2    18
# 26                          曬個萌樣來雪恥💪  2019-12-02T08:01:07.477Z     1    17
# 27                    #圖 板橋貓咪走失（已找到）  2019-12-02T03:50:17.266Z     3    15
# 28                            表情很浮誇喔  2019-12-02T15:36:01.429Z     0    14
# 29                          我怎麼就沒資格了  2019-12-03T00:58:21.934Z     5    13

# %%
# 非熱門文章
df_npop_r = df_npop[['title', 'createdAt', 'commentCount', 'likeCount']]
df_npop_r.columns = cols_name
print('非熱門文章:\n')
df_npop_r
# Out:
# 非熱門文章:
#                                標題                      貼文時間  留言人數  按讚人數
# 0                  我發誓牠們的食物是一樣的……  2019-12-02T15:47:50.672Z     0     0
# 1                          表情很浮誇喔  2019-12-02T15:36:01.429Z     0     1
# 2                           中台小貓咪  2019-12-02T15:28:25.729Z     0     2
# 3                    基隆大武崙 鸚鵡尋主人！  2019-12-02T15:13:19.520Z     0     1
# 4                        直接抓到犯罪證據  2019-12-02T14:43:24.475Z     0     5
# 5                        你怎麼站起來了！  2019-12-02T14:42:42.738Z     3    11
# 6                       我有一隻可愛的來福  2019-12-02T14:32:37.716Z     1     6
# 7           問個 有人有養過粗鱗武昌和水中的變葉木嗎？  2019-12-02T13:53:38.510Z     1     0
# 8                         守宮身上白白的  2019-12-02T13:43:21.599Z     2     1
# 9                     床要被你們壓壞啦啊啊啊  2019-12-02T13:09:49.509Z     3     7
# 10                         來蓋吉娃娃樓  2019-12-02T13:09:02.202Z     6     4
# 11                      求淡水貓咪美容推薦  2019-12-02T12:48:41.547Z     0     0
# 12                 心絲蟲的預防外用液劑 #家貓  2019-12-02T12:32:51.058Z     4     0
# 13  可以幫忙填一下有關貓咪的問卷嗎(｡º̩̩́⌓º̩̩̀).゜  2019-12-02T12:28:37.374Z     2     5
# 14                 #認同請分享 寵物的長輩圖😂  2019-12-02T12:21:44.614Z     2     2
# 15                         同學你的貓貓  2019-12-02T12:11:28.555Z     9    27
# 16           我到底養了什麼貓....（...微西斯）  2019-12-02T11:45:50.709Z     5    37
# 17                    #圖多 萬用的奴才肩膀  2019-12-02T10:49:21.771Z     0     8
# 18                  你這樣好像我都不給你吃一樣  2019-12-02T10:08:57.832Z     2     3
# 19                         是我太髒嗎?  2019-12-02T09:16:23.658Z     3    18
# 20                  淘寶訂可爾必斯送來...?  2019-12-02T08:32:40.657Z     3     8
# 21                  有這麼不爽嗎(･ัω･ั)  2019-12-02T08:31:17.626Z     5    46
# 22                          母狗結紮後  2019-12-02T08:09:03.586Z     2     0
# 23                       曬個萌樣來雪恥💪  2019-12-02T08:01:07.477Z     1     9
# 24                        我家曠世怨婦🐱  2019-12-02T06:56:01.120Z     0    13
# 25                         我家的老阿公  2019-12-02T06:22:36.958Z     2    23
# 26                        大型犬養在戶外  2019-12-02T06:05:08.319Z     0     1
# 27                      若要抱貓，必先成貓  2019-12-02T05:44:06.710Z     0    13
# 28                     餵養的浪貓得了乳腺瘤  2019-12-02T05:29:49.540Z     4    57
# 29                          這是什麼🤔  2019-12-02T05:08:54.080Z     5     3

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

print('熱門文章-平均留言人數:', df_pop_r['留言人數'].mean())
print('熱門文章-平均按讚人數:', df_pop_r['按讚人數'].mean())
print('非熱門文章-平均留言人數:', df_npop_r['留言人數'].mean())
print('非熱門文章-平均按讚人數:', df_npop_r['按讚人數'].mean())
# Out:
# 熱門文章-平均留言人數: 7.133333333333334
# 熱門文章-平均按讚人數: 396.1666666666667
# 非熱門文章-平均留言人數: 2.1666666666666665
# 非熱門文章-平均按讚人數: 10.366666666666667
